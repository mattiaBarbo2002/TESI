# %% [markdown]
# **1. CONVOLUTIONAL AUTOENCODERS TRAINING**

# %%
import digitalhub as dh
import pandas as pd
import matplotlib.pyplot as plt

NOME_PROGETTO = "floods"
project = dh.get_project(NOME_PROGETTO)
print(f"Progetto: {project.name}")
# Out:
# Progetto: floods

# %% [markdown]
# **SETUP PARAMETERS**

# %%
# Parametri Job   
job_name = "numpy_as_artifact_standard"                                
dataset = "Standard"                                 
#handler = pretrain_encoders                                         

parametri = {     
    "dataset": dataset,
    "patch_size": 256,
    "n_images1": 4, "n_channels1": 2,   # SAR
    "n_images2": 4, "n_channels2": 10,  # OPT
}                                                              

print(f"PARAMETRI: {parametri}")

# volume -> circa 400 GB dataset Standard
volumi = [
    {
        "volume_type": "ephemeral",
        "name": "volume-spazio-dati",
        "mount_path": "/data",      
        "spec": {"size": "500Gi"}   
    }
]
# Out:
# PARAMETRI: {'dataset': 'Standard', 'patch_size': 256, 'n_images1': 4, 'n_channels1': 2, 'n_images2': 4, 'n_channels2': 10}

# %% [markdown]
# **BUILD ENVIRONMENT**

# %%
test_train_func = project.new_function(
    name= f'encoders-Floods_{dataset}_{job_name}',
    kind="python",
    python_version="PYTHON3_10",
    code_src="../src/", 
    handler="crop_norm_artifact", 
    base_image="pytorch/pytorch:2.1.2-cuda11.8-cudnn8-runtime",
    requirements=["pandas==2.3.3", "numpy==1.26.4", "rasterio==1.4.4", "tqdm==4.70.0", "tifffile==2024.8.30", "torch==2.1.2", "matplotlib==3.10.9", "digitalhub==0.15.11", "digitalhub-runtime-python==0.15.2"]
)

# .run("build") -> scarica immagine, installa requirements, copia intera cartella code_src, crea immagine docker

build = test_train_func.run("build", wait=True)
print(f"BUILD: {build.status.state}")
# Out:
# 2026-09-21 15:25:37,730 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 72bc00e517804798b6a27937250034d8 to finish...
# 2026-09-21 15:25:42,737 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 72bc00e517804798b6a27937250034d8 to finish...
# 2026-09-21 15:25:47,764 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 72bc00e517804798b6a27937250034d8 to finish...
# 2026-09-21 15:25:52,772 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 72bc00e517804798b6a27937250034d8 to finish...
# 2026-09-21 15:25:57,780 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 72bc00e517804798b6a27937250034d8 to finish...
# 2026-09-21 15:26:02,789 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 72bc00e517804798b6a27937250034d8 to finish...
# 2026-09-21 15:26:07,798 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 72bc00e517804798b6a27937250034d8 to finish...
# 2026-09-21 15:26:12,912 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 72bc00e517804798b6a27937250034d8 to finish...
# 2026-09-21 15:26:18,025 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 72bc00e517804798b6a27937250034d8 to finish...
# 2026-09-21 15:26:23,033 - dhcore.digitalhub.entities.run._base.entity - INFO - Run 72bc00e517804798b6a27937250034d8 finished in 45.30 seconds.
# BUILD: COMPLETED

# %% [markdown]
# **TRAINING**

# %%
# action job = avvia container, esegue script, libera risorse

run_test_encoders = test_train_func.run(
    action="job", 
    parameters=parametri, 
    volumes=volumi, 
    profile="1xv100-shared",                                       # 1x = 1 gpu
    # local_execution= True,                                
    wait=True
)

print(f"Run test_encoders avviato: {run_test_encoders.id}")
print(run_test_encoders.status.state)
print(run_test_encoders.status.message)
# Out:
# 2026-09-21 15:26:23,088 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:26:28,094 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:26:33,102 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:26:38,111 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:26:43,119 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:26:48,128 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:26:53,137 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:26:58,145 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:27:03,153 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:27:08,161 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:27:13,170 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:27:18,179 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:27:23,189 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:27:28,197 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:27:33,205 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:27:38,320 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:27:43,328 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:27:48,337 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:27:53,345 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:27:58,353 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:28:03,362 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:28:08,371 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:28:13,379 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:28:18,387 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:28:23,395 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
# 2026-09-21 15:28:28,404 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 4d6ae39f99e9430fa2d1105853f573fb to finish...
