# %% [markdown]
# **1. CONVOLUTIONAL AUTOENCODERS TRAINING**

# %%
import digitalhub as dh
import pandas as pd
import matplotlib.pyplot as plt

NOME_PROGETTO = "floods"
project = dh.get_project(NOME_PROGETTO)
print(f"Progetto: {project.name}")
# Out:
# Progetto: floods

# %% [markdown]
# **SETUP PARAMETERS**

# %%
# Parametri Job   
job_name = "numpy_as_artifact_standard"                                
dataset = "Standard"                                 
#handler = pretrain_encoders                                         

parametri = {     
    "dataset": dataset,
    "patch_size": 256,
    "n_images1": 4, "n_channels1": 2,   # SAR
    "n_images2": 4, "n_channels2": 10,  # OPT
}                                                              

print(f"PARAMETRI: {parametri}")

# volume -> circa 400 GB dataset Standard
volumi = [
    {
        "volume_type": "ephemeral",
        "name": "volume-spazio-dati",
        "mount_path": "/data",      
        "spec": {"size": "500Gi"}   
    }
]
# Out:
# PARAMETRI: {'dataset': 'Standard', 'patch_size': 256, 'n_images1': 4, 'n_channels1': 2, 'n_images2': 4, 'n_channels2': 10}

# %% [markdown]
# **BUILD ENVIRONMENT**

# %%
test_train_func = project.new_function(
    name= f'encoders-Floods_{dataset}_{job_name}',
    kind="python",
    python_version="PYTHON3_10",
    code_src="../src/", 
    handler="crop_norm_artifact", 
    base_image="pytorch/pytorch:2.1.2-cuda11.8-cudnn8-runtime",
    requirements=["pandas==2.3.3", "numpy==1.26.4", "rasterio==1.4.4", "tqdm==4.70.0", "tifffile==2024.8.30", "torch==2.1.2", "matplotlib==3.10.9", "digitalhub==0.15.11", "digitalhub-runtime-python==0.15.2"]
)

# .run("build") -> scarica immagine, installa requirements, copia intera cartella code_src, crea immagine docker

build = test_train_func.run("build", wait=True)
print(f"BUILD: {build.status.state}")
# Out:
# 2026-09-21 15:25:37,730 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 72bc00e517804798b6a27937250034d8 to finish...
# 2026-09-21 15:25:42,737 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 72bc00e517804798b6a27937250034d8 to finish...
# 2026-09-21 15:25:47,764 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 72bc00e517804798b6a27937250034d8 to finish...

# %% [markdown]
# **TRAINING**

# %%
# action job = avvia container, esegue script, libera risorse

run_test_encoders = test_train_func.run(
    action="job", 
    parameters=parametri, 
    volumes=volumi, 
    profile="1xv100-shared",                                       # 1x = 1 gpu
    # local_execution= True,                                
    wait=True
)

print(f"Run test_encoders avviato: {run_test_encoders.id}")
print(run_test_encoders.status.state)
print(run_test_encoders.status.message)
# Out:
# 2026-09-21 14:13:09,292 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:13:14,300 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:13:19,308 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:13:24,316 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:13:29,325 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:13:34,333 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:13:39,342 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:13:44,453 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:13:49,569 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:13:54,579 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:13:59,587 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:14:04,596 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:14:09,605 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:14:14,613 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:14:19,727 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:14:24,735 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:14:29,743 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:14:34,752 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:14:39,760 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:14:44,769 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:14:49,779 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:14:54,789 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:14:59,905 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:15:04,913 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:15:09,921 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:15:14,930 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:15:19,938 - dhcore.digitalhub.entities.run._base.entity - INFO - Waiting for run 76ad698988d54dd0a45b00ed9fbc1d92 to finish...
# 2026-09-21 14:15:25,052 - dhcore.digitalhub.entities.run._base.entity - INFO - Run 76ad698988d54dd0a45b00ed9fbc1d92 finished in 135.76 seconds.
# Run test_encoders avviato: 76ad698988d54dd0a45b00ed9fbc1d92
# COMPLETED
# None
