# %%
# 1. Test di output testuale
print("👋 Ciao! Se leggi questo, il Kernel Python è connesso e funzionante.")
# Out:
# 👋 Ciao! Se leggi questo, il Kernel Python è connesso e funzionante.

# %%
# 2. Test di calcolo e gestione delle variabili
a = 5
b = 7
somma = a + b
print(f"La somma di {a} e {b} è: {somma}")

# 3. Test di elaborazione dati nativa (crea una lista dei quadrati dei numeri da 1 a 5)
numeri_quadrati = [x**2 for x in range(1, 6)]

# Nei notebook, scrivere il nome di una variabile alla fine della cella
# ne mostra automaticamente il contenuto come output, senza usare la funzione print()
numeri_quadrati
# Out:
# La somma di 5 e 7 è: 12
# [1, 4, 9, 16, 25]
